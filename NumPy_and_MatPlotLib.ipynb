# %% [markdown]
# <a href="https://colab.research.google.com/github/devpandey01/Introduction-to-Dl-AI/blob/main/NumPy_and_MatPlotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # **Partitioning the real line**
#
# partition is done using numPy and plotting is done using matplotlib

# %%
x = np.linspace(0,1,11) # 11 numbers equally spaced between [0,1]
x
y = np.linspace(0,1,5) # 5 numbers equally spaced between [0,1]

# %% [markdown]
# `np.linspace()` generate a sequence of 11 numbers starting from 0 to 1 with equal spacing. We could also use `np.arange()` using a step function of 0.1 and end-point that is greater than 1. Interval is self-generated. By default, `np.linspace()` divides the range into 50 equally spaced points

# %%
x.shape
# Out:
# (11,)

# %% [markdown]
# # Curve-1 : Line Plot
#
# Plot y = x for x ∈ [0,1]. Sample 10 equally spaced points in this interval

# %%
x = np.linspace(0,1,10)
y = x
plt.scatter(x,y);
plt.plot(x,y);

# %% [markdown]
# # Alternative Method to plot curve using `np.array`

# %%
x = np.array([0,1])
y = x
plt.scatter(x,y);
plt.plot(x,y);

# %% [markdown]
# # Curve-2 : y = 5 - 3x
#
# Plot `y = 5 - 3x` for x ∈ [-5,5]. Sample 20 equally spaced points in this interval, inclusive of endpoints. Add a title to the plot which has the equation of curve.

# %%
x = np.linspace(-5,5,20)
y = 5 - 3*x
plt.scatter(x,y);
plt.plot(x,y);
plt.title("y = 5 - 3x");

# %% [markdown]
# # Curve-3 : $y = x^{2}$
#
# Plot $y = x^{2}$ for x ∈ [-1,1].
#
# *   5 equally spaced points in the interval, inclusive of endpoints
# *   10 equally spaced points in the interval, inclusive of endpoints
# *   20 equally spaced points in the interval, inclusive of endpoints
# *   50 equally spaced points in the interval, inclusive of endpoints
#
# Add title and axis labels to the plot

# %%
x = np.linspace(-1,1,5)
y = x**2
plt.scatter(x,y);
plt.plot(x,y);
plt.title("$y = x^{2}$");
plt.xlabel("x");
plt.ylabel("y");

# %%
x = np.linspace(-1,1,10)
y = x**2
plt.scatter(x,y);
plt.plot(x,y);
plt.title("$y = x^{2}$");
plt.xlabel("x");
plt.ylabel("y");

# %%
x = np.linspace(-1,1,20)
y = x**2
plt.scatter(x,y);
plt.plot(x,y);
plt.title("$y = x^{2}$");
plt.xlabel("x");
plt.ylabel("y");

# %%
x = np.linspace(-1,1,50)
y = x**2
plt.plot(x,y);
plt.title("$y = x^{2}$");
plt.xlabel("x");
plt.ylabel("y");
plt.axhline(color = 'black', linestyle = '--' ,linewidth = 0.8);
plt.axvline(color = 'black', linestyle = '--' ,linewidth = 0.8);

# %% [markdown]
# ***Note that as you increase the number of equally spaced points, the graph gets smoother. The shape of parabola gets more defined***

# %% [markdown]
# # Curve-4 : Exercise
#
# Plot `y = 3` and `x = 5` on the same plot. Color the first one blue and second one red. Limit the plot to the region x ∈ [0,6] and y ∈ [0,6]
#
#
# *   Label x and y axes
# *   Add a suitable title
# *   Add a legend

# %%
x = np.linspace(0,6,50);
y = np.linspace(0,6,50);

plt.plot(x,3*y,color = 'blue');
plt.plot(5*x,y,color = 'red');
plt.xlabel("x");
plt.ylabel("y");
plt.title("y = 3 and x = 5");

# %% [markdown]
# # Subplots
#
# `plt.subplot(r,c,ind)` divides the plotting region into `r x c` individual plotting windows and selects the plot at index `ind`. The index is set to 1 for the top-left plot and increases by one point from left to right and top to bottom. The top-left plot window has index 1 and the last window has index c.
#
# $y = ln x$, $x ∈ (\frac{1}{e^{2}}$, $e^{3}$)
#
# $y = e^{x}$, $x ∈ (0, 3$)
#
# $y = sin x, x ∈ [0,2π]$
#
# $y = \frac{1}{x}, x \in (1,5)$

# %%
plt.rcParams['figure.figsize'] = [8,8]

# %%
plt.subplot(2,2,1);
x = np.linspace(1/np.e**2,np.e**3)
y = np.log(x)
plt.plot(x,y);
plt.title("$y = ln x$");

plt.subplot(2,2,2);
x = np.linspace(0,3)
y = np.exp(x)
plt.plot(x,y);
plt.title("$y = e^{x}$");

plt.subplot(2,2,3);
x = np.linspace(0,2*np.pi)
y = np.sin(x)
plt.plot(x,y);
plt.title("$y = sin x$");

plt.subplot(2,2,4)
x = np.linspace(1,5)
y = 1/x
plt.plot(x,y);
plt.title(r'$y = 1/x$');
